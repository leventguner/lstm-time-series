# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    """
    dataset: whole dataset (np array)
    target: target column of whole dataset (put dataset if it has single variable) (np array)
    start_index: starting index of the dataset
    end_index: ending index of the dataset (put None if end index is the last element of dataset)
    history_size: how many data points should appear in past history
    target_size: how many data points you want to predict for future
    step: step size
    single_step: is single step
    """
    
    data = []
    labels = []
    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
dataset = np.sin(np.arange(300)) + np.random.rand(300)*0.5 #create a sinusoidal dataset with some randomness
dataset = dataset.reshape(len(dataset),1)
dataset[:5]
# Out:
# array([[ 0.1555239 ],
#        [ 1.08992751],
#        [ 0.99314795],
#        [ 0.60832061],
#        [-0.64116288]])

# %%
plt.figure(figsize=(8,5))
plt.plot(dataset)

# %%
#scale the data
sca = MinMaxScaler()
dataset = sca.fit_transform(dataset)

# %%
#train-test split and prepare data for time series

TRAIN_SPLIT = int(len(dataset)*0.7) #how many data in train
past_history = 10 #how many data to look in the past for prediction
future_target = 1 #how many data to predict in the future
STEP = 1 #step size

X_train, y_train = multivariate_data(dataset, dataset[:,0], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)

X_test, y_test = multivariate_data(dataset, dataset[:,0], TRAIN_SPLIT,
                                             None, past_history,
                                             future_target, STEP)
print(X_train.shape)

#reshape dataset in case of need
if len(X_train.shape)==2:
    X_train = X_train.reshape((X_train.shape[0],X_train.shape[1],1))
    
if len(X_test.shape)==2:
    X_test = X_test.reshape((X_test.shape[0],X_test.shape[1],1))
# Out:
# (200, 10, 1)

# %%
X_train.shape, y_train.shape
# Out:
# ((200, 10, 1), (200, 1))

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(8, input_shape=(X_train.shape[1],X_train.shape[2])))
#model.add(keras.layers.LSTM(units=64))
model.add(keras.layers.Dense(y_train.shape[1]))

model.compile(loss='mean_squared_error',
              optimizer=keras.optimizers.Adam(0.001))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 8)                 320
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 329
# Trainable params: 329
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
        X_train, y_train, 
        epochs=70, 
        batch_size=4, 
        validation_split=0.1, 
        verbose=1, 
        shuffle=False
        )
# Out:
# Train on 180 samples, validate on 20 samples
# Epoch 1/70
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.3852 - val_loss: 0.2527
# Epoch 2/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.1462 - val_loss: 0.1093
# Epoch 3/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0954 - val_loss: 0.0993
# Epoch 4/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0936 - val_loss: 0.0982
# Epoch 5/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0922 - val_loss: 0.0967
# Epoch 6/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0909 - val_loss: 0.0951
# Epoch 7/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0894 - val_loss: 0.0935
# Epoch 8/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0879 - val_loss: 0.0917
# Epoch 9/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0862 - val_loss: 0.0898
# Epoch 10/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0843 - val_loss: 0.0877
# Epoch 11/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0822 - val_loss: 0.0852
# Epoch 12/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0798 - val_loss: 0.0824
# Epoch 13/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0770 - val_loss: 0.0791
# Epoch 14/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0738 - val_loss: 0.0755
# Epoch 15/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0701 - val_loss: 0.0713
# Epoch 16/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0661 - val_loss: 0.0667
# Epoch 17/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0615 - val_loss: 0.0615
# Epoch 18/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0562 - val_loss: 0.0555
# Epoch 19/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0501 - val_loss: 0.0479
# Epoch 20/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0427 - val_loss: 0.0385
# Epoch 21/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0339 - val_loss: 0.0275
# Epoch 22/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0236 - val_loss: 0.0273
# Epoch 23/70
# 180/180 [==============================] - 0s 2ms/sample - loss: 0.0152 - val_loss: 0.0278
# Epoch 24/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0122 - val_loss: 0.0266
# Epoch 25/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0114 - val_loss: 0.0248
# Epoch 26/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0112 - val_loss: 0.0229
# Epoch 27/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0115 - val_loss: 0.0198
# Epoch 28/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0121 - val_loss: 0.0153
# Epoch 29/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0127 - val_loss: 0.0107
# Epoch 30/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0128 - val_loss: 0.0077
# Epoch 31/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0123 - val_loss: 0.0066
# Epoch 32/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0115 - val_loss: 0.0062
# Epoch 33/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0109 - val_loss: 0.0059
# Epoch 34/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0104 - val_loss: 0.0058
# Epoch 35/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0100 - val_loss: 0.0057
# Epoch 36/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0096 - val_loss: 0.0056
# Epoch 37/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0093 - val_loss: 0.0055
# Epoch 38/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0091 - val_loss: 0.0054
# Epoch 39/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0089 - val_loss: 0.0053
# Epoch 40/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0087 - val_loss: 0.0053
# Epoch 41/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0085 - val_loss: 0.0052
# Epoch 42/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0083 - val_loss: 0.0051
# Epoch 43/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0082 - val_loss: 0.0051
# Epoch 44/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0080 - val_loss: 0.0050
# Epoch 45/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0079 - val_loss: 0.0050
# Epoch 46/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0078 - val_loss: 0.0049
# Epoch 47/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0077 - val_loss: 0.0049
# Epoch 48/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0076 - val_loss: 0.0049
# Epoch 49/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0075 - val_loss: 0.0048
# Epoch 50/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0074 - val_loss: 0.0048
# Epoch 51/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0073 - val_loss: 0.0047
# Epoch 52/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0073 - val_loss: 0.0047
# Epoch 53/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0072 - val_loss: 0.0047
# Epoch 54/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0071 - val_loss: 0.0046
# Epoch 55/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0070 - val_loss: 0.0046
# Epoch 56/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0070 - val_loss: 0.0046
# Epoch 57/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0069 - val_loss: 0.0045
# Epoch 58/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0069 - val_loss: 0.0045
# Epoch 59/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0068 - val_loss: 0.0045
# Epoch 60/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0067 - val_loss: 0.0044
# Epoch 61/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0067 - val_loss: 0.0044
# Epoch 62/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0066 - val_loss: 0.0044
# Epoch 63/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0066 - val_loss: 0.0044
# Epoch 64/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0065 - val_loss: 0.0043
# Epoch 65/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0065 - val_loss: 0.0043
# Epoch 66/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0065 - val_loss: 0.0043
# Epoch 67/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0064 - val_loss: 0.0043
# Epoch 68/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0064 - val_loss: 0.0043
# Epoch 69/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0063 - val_loss: 0.0042
# Epoch 70/70
# 180/180 [==============================] - 0s 1ms/sample - loss: 0.0063 - val_loss: 0.0042

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)

# %%
plt.figure(figsize=(8,5))

plt.plot(np.arange(0, len(y_train)), y_train, 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
plt.figure(figsize=(8,5))
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();
